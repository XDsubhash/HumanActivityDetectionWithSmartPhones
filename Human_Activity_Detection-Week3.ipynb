# %% [markdown]
#  <H1> Human Activity Recognition Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.manifold import TSNE

# %%
train = pd.read_csv('./project_dataset/train.csv')
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
train.shape
# Out:
# (7352, 563)

# %%
test = pd.read_csv('./project_dataset/test.csv')
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
train.shape
# Out:
# (7352, 563)

# %% [markdown]
# <H2> Data Cleaning <H2>

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %%
#check for data imbalance

# %%
sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize =(20,10))
plt.title('Data provided by each user',fontsize=24)
sns.countplot(x='subject',hue='Activity',data=train)
plt.show()

# %%
plt.title('No of datapoints per activity',fontsize=16)
sns.countplot(train.Activity)
plt.xticks(rotation=90)
plt.show()

# %%
train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
columns = train.columns

#Removing '()' from column names

columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]','')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

train.columns
test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
train.to_csv('f_train.csv',index=False)
test.to_csv('f_test.csv',index=False)

# %% [markdown]
# <H2> Exploratory Data Analysis<H2>
#
#     Feature Engineering

# %% [markdown]
# `1.` <b>Static and Dynamic Activities<b>
#
# `-->`Static Activities --> sit,stand,lie down
#
# `-->`Dynamic Activities --> Walking, Walking_upstairs,Walking_upstairs

# %%
sns.set_palette("colorblind", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Activity', height=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()


plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops= dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))


plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops= dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %%
# For plotting purposes taking datapoints of each activity to a different dataframes


df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(12,8))

plt.subplot(1,2,1)

plt.title("Static Activities(Closer view)")
sns.distplot(train[train["Activity"]=="SITTING"]['tBodyAccMagmean'],hist = False ,label = 'Sitting')

sns.distplot(train[train["Activity"]=="STANDING"]['tBodyAccMagmean'],hist = False ,label = 'Standing')

sns.distplot(train[train["Activity"]=="LAYING"]['tBodyAccMagmean'],hist = False ,label = 'Laying')

plt.legend()


plt.axis([-1.02, -0.5, 0, 35])
plt.subplot(1,2,2)

plt.title("Dynamic Activities(closer view)")

sns.distplot(train[train["Activity"]=="WALKING"]['tBodyAccMagmean'],hist = False ,label = 'Walking')

sns.distplot(train[train["Activity"]=="WALKING_DOWNSTAIRS"]['tBodyAccMagmean'],hist = False ,label = 'Walking_upstairs')

sns.distplot(train[train["Activity"]=="WALKING_UPSTAIRS"]['tBodyAccMagmean'],hist = False ,label = 'Walking_downstairs')

plt.legend()

# %% [markdown]
# <h3> 2. Magnitude of an acceleration can separate it well<h3>

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='Activity',y='tBodyAccMagmean',data=train,showfliers = False ,saturation=1)

plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7,xmin=0.0,xmax=0.7,dashes=(5,5),c='g')
plt.axhline(y=-0.5,xmin=0.4,dashes=(5,5),c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h2> Observation <h3>
#
# -->If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
#
# -->If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
#
# -->If tAccMean > 0.0 then the Activity is WalkingDownstairs.
#
# -->We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# <h4> Position of GravityAccelerationComponants also matters <h4>

# %%
sns.boxplot(x='Activity',y='angleXgravityMean',data=train)
plt.axhline(y=0.08,xmin=0.1,xmax=0.9,c='m',dashes=(5,3))
plt.title("Angle between X-axis and Gravity_mean",fontsize=15)
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# <h3>Observations:<h3>
#
# If angleX,gravityMean > 0 then Activity is Laying.
#
# We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='Activity', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# <h3>Observations:<h3>
#
# If angleYgravityMean < -0.2 then Activity is Laying.
#
# We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %% [markdown]
# <H2> Apply t-sne on the data<H2>

# %% [markdown]
# Here we will see these datapoints in 2 dimensions and try to observe the behaviour of the datapoints

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=3000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity'], axis=1)
y_pre_tsne = train['Activity']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[5,10,20,30,50])
# Out:
# performing tsne with perplexity 5 and with 3000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 1.077s...
# [t-SNE] Computed neighbors for 7352 samples in 45.865s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.081s
# [t-SNE] Iteration 50: error = 114.1721802, gradient norm = 0.0176181 (50 iterations in 4.298s)
# [t-SNE] Iteration 100: error = 97.6194000, gradient norm = 0.0153555 (50 iterations in 2.006s)
# [t-SNE] Iteration 150: error = 93.1975098, gradient norm = 0.0098629 (50 iterations in 1.662s)
# [t-SNE] Iteration 200: error = 91.1977615, gradient norm = 0.0061150 (50 iterations in 1.957s)
# [t-SNE] Iteration 250: error = 90.0236053, gradient norm = 0.0047362 (50 iterations in 1.616s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.023605
# [t-SNE] Iteration 300: error = 3.5715878, gradient norm = 0.0014599 (50 iterations in 1.654s)
# [t-SNE] Iteration 350: error = 2.8130713, gradient norm = 0.0007483 (50 iterations in 1.911s)
# [t-SNE] Iteration 400: error = 2.4318018, gradient norm = 0.0005289 (50 iterations in 1.672s)
# [t-SNE] Iteration 450: error = 2.2136240, gradient norm = 0.0004075 (50 iterations in 1.827s)
# [t-SNE] Iteration 500: error = 2.0686336, gradient norm = 0.0003331 (50 iterations in 1.623s)
# [t-SNE] Iteration 550: error = 1.9635609, gradient norm = 0.0002828 (50 iterations in 1.768s)
# [t-SNE] Iteration 600: error = 1.8824809, gradient norm = 0.0002452 (50 iterations in 1.570s)
# [t-SNE] Iteration 650: error = 1.8171327, gradient norm = 0.0002203 (50 iterations in 1.560s)
# [t-SNE] Iteration 700: error = 1.7634597, gradient norm = 0.0001955 (50 iterations in 1.533s)
# [t-SNE] Iteration 750: error = 1.7181696, gradient norm = 0.0001794 (50 iterations in 1.544s)
# [t-SNE] Iteration 800: error = 1.6792505, gradient norm = 0.0001641 (50 iterations in 1.675s)
# [t-SNE] Iteration 850: error = 1.6453669, gradient norm = 0.0001535 (50 iterations in 1.783s)
# [t-SNE] Iteration 900: error = 1.6154674, gradient norm = 0.0001437 (50 iterations in 1.830s)
# [t-SNE] Iteration 950: error = 1.5890598, gradient norm = 0.0001325 (50 iterations in 1.693s)
# [t-SNE] Iteration 1000: error = 1.5653018, gradient norm = 0.0001252 (50 iterations in 1.532s)
# [t-SNE] KL divergence after 1000 iterations: 1.565302
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 3000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.853s...
# [t-SNE] Computed neighbors for 7352 samples in 40.938s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.082s
# [t-SNE] Iteration 50: error = 105.8396759, gradient norm = 0.0181464 (50 iterations in 3.286s)
# [t-SNE] Iteration 100: error = 90.2601471, gradient norm = 0.0100959 (50 iterations in 2.266s)
# [t-SNE] Iteration 150: error = 87.2200317, gradient norm = 0.0051764 (50 iterations in 1.923s)
# [t-SNE] Iteration 200: error = 86.0034714, gradient norm = 0.0039713 (50 iterations in 1.895s)
# [t-SNE] Iteration 250: error = 85.3168182, gradient norm = 0.0027039 (50 iterations in 1.855s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.316818
# [t-SNE] Iteration 300: error = 3.1309023, gradient norm = 0.0014024 (50 iterations in 2.025s)
# [t-SNE] Iteration 350: error = 2.4864326, gradient norm = 0.0006487 (50 iterations in 1.619s)
# [t-SNE] Iteration 400: error = 2.1661639, gradient norm = 0.0004213 (50 iterations in 2.019s)
# [t-SNE] Iteration 450: error = 1.9813836, gradient norm = 0.0003157 (50 iterations in 2.108s)
# [t-SNE] Iteration 500: error = 1.8635283, gradient norm = 0.0002543 (50 iterations in 1.665s)
# [t-SNE] Iteration 550: error = 1.7804216, gradient norm = 0.0002101 (50 iterations in 1.958s)
# [t-SNE] Iteration 600: error = 1.7178062, gradient norm = 0.0001796 (50 iterations in 2.144s)
# [t-SNE] Iteration 650: error = 1.6689680, gradient norm = 0.0001587 (50 iterations in 2.063s)
# [t-SNE] Iteration 700: error = 1.6293463, gradient norm = 0.0001413 (50 iterations in 1.946s)
# [t-SNE] Iteration 750: error = 1.5966606, gradient norm = 0.0001285 (50 iterations in 2.044s)
# [t-SNE] Iteration 800: error = 1.5692363, gradient norm = 0.0001184 (50 iterations in 2.060s)
# [t-SNE] Iteration 850: error = 1.5459976, gradient norm = 0.0001100 (50 iterations in 1.829s)
# [t-SNE] Iteration 900: error = 1.5257871, gradient norm = 0.0001036 (50 iterations in 1.867s)
# [t-SNE] Iteration 950: error = 1.5086682, gradient norm = 0.0000949 (50 iterations in 2.057s)
# [t-SNE] Iteration 1000: error = 1.4933584, gradient norm = 0.0000923 (50 iterations in 1.819s)
# [t-SNE] KL divergence after 1000 iterations: 1.493358
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 3000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.861s...
# [t-SNE] Computed neighbors for 7352 samples in 42.557s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.192s
# [t-SNE] Iteration 50: error = 97.6793289, gradient norm = 0.0142458 (50 iterations in 2.375s)
# [t-SNE] Iteration 100: error = 84.2931900, gradient norm = 0.0069218 (50 iterations in 2.026s)
# [t-SNE] Iteration 150: error = 82.1695251, gradient norm = 0.0073945 (50 iterations in 1.845s)
# [t-SNE] Iteration 200: error = 81.4366760, gradient norm = 0.0027220 (50 iterations in 2.065s)
# [t-SNE] Iteration 250: error = 81.0480118, gradient norm = 0.0019714 (50 iterations in 2.072s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.048012
# [t-SNE] Iteration 300: error = 2.7230630, gradient norm = 0.0013021 (50 iterations in 2.211s)
# [t-SNE] Iteration 350: error = 2.1919367, gradient norm = 0.0005785 (50 iterations in 2.039s)
# [t-SNE] Iteration 400: error = 1.9413517, gradient norm = 0.0003520 (50 iterations in 2.073s)
# [t-SNE] Iteration 450: error = 1.7942206, gradient norm = 0.0002506 (50 iterations in 1.964s)
# [t-SNE] Iteration 500: error = 1.6996648, gradient norm = 0.0001963 (50 iterations in 1.895s)
# [t-SNE] Iteration 550: error = 1.6344368, gradient norm = 0.0001620 (50 iterations in 2.026s)
# [t-SNE] Iteration 600: error = 1.5873393, gradient norm = 0.0001378 (50 iterations in 2.522s)
# [t-SNE] Iteration 650: error = 1.5515565, gradient norm = 0.0001233 (50 iterations in 2.564s)
# [t-SNE] Iteration 700: error = 1.5234487, gradient norm = 0.0001098 (50 iterations in 2.498s)
# [t-SNE] Iteration 750: error = 1.5010531, gradient norm = 0.0000993 (50 iterations in 1.841s)
# [t-SNE] Iteration 800: error = 1.4829792, gradient norm = 0.0000921 (50 iterations in 2.296s)
# [t-SNE] Iteration 850: error = 1.4682072, gradient norm = 0.0000874 (50 iterations in 2.543s)
# [t-SNE] Iteration 900: error = 1.4556994, gradient norm = 0.0000822 (50 iterations in 1.937s)
# [t-SNE] Iteration 950: error = 1.4454186, gradient norm = 0.0000781 (50 iterations in 1.744s)
# [t-SNE] Iteration 1000: error = 1.4367355, gradient norm = 0.0000726 (50 iterations in 1.648s)
# [t-SNE] KL divergence after 1000 iterations: 1.436736
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 30 and with 3000 iterations at max
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.883s...
# [t-SNE] Computed neighbors for 7352 samples in 44.051s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.348516
# [t-SNE] Computed conditional probabilities in 0.502s
# [t-SNE] Iteration 50: error = 90.7855911, gradient norm = 0.0363026 (50 iterations in 2.745s)
# [t-SNE] Iteration 100: error = 80.3029099, gradient norm = 0.0052053 (50 iterations in 2.463s)
# [t-SNE] Iteration 150: error = 78.7496414, gradient norm = 0.0029541 (50 iterations in 3.009s)
# [t-SNE] Iteration 200: error = 78.2533951, gradient norm = 0.0017628 (50 iterations in 2.879s)
# [t-SNE] Iteration 250: error = 77.9903412, gradient norm = 0.0020795 (50 iterations in 2.736s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.990341
# [t-SNE] Iteration 300: error = 2.4573121, gradient norm = 0.0012583 (50 iterations in 2.766s)
# [t-SNE] Iteration 350: error = 1.9808702, gradient norm = 0.0005377 (50 iterations in 2.514s)
# [t-SNE] Iteration 400: error = 1.7679869, gradient norm = 0.0003179 (50 iterations in 2.625s)
# [t-SNE] Iteration 450: error = 1.6458832, gradient norm = 0.0002184 (50 iterations in 2.947s)
# [t-SNE] Iteration 500: error = 1.5666212, gradient norm = 0.0001666 (50 iterations in 2.544s)
# [t-SNE] Iteration 550: error = 1.5124376, gradient norm = 0.0001361 (50 iterations in 1.858s)
# [t-SNE] Iteration 600: error = 1.4738696, gradient norm = 0.0001150 (50 iterations in 2.029s)
# [t-SNE] Iteration 650: error = 1.4454743, gradient norm = 0.0001014 (50 iterations in 2.354s)
# [t-SNE] Iteration 700: error = 1.4239876, gradient norm = 0.0000909 (50 iterations in 2.024s)
# [t-SNE] Iteration 750: error = 1.4078487, gradient norm = 0.0000837 (50 iterations in 1.873s)
# [t-SNE] Iteration 800: error = 1.3953089, gradient norm = 0.0000790 (50 iterations in 1.853s)
# [t-SNE] Iteration 850: error = 1.3851839, gradient norm = 0.0000737 (50 iterations in 1.690s)
# [t-SNE] Iteration 900: error = 1.3765808, gradient norm = 0.0000724 (50 iterations in 1.908s)
# [t-SNE] Iteration 950: error = 1.3692995, gradient norm = 0.0000662 (50 iterations in 1.695s)
# [t-SNE] Iteration 1000: error = 1.3627548, gradient norm = 0.0000635 (50 iterations in 1.706s)
# [t-SNE] KL divergence after 1000 iterations: 1.362755
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 3000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.774s...
# [t-SNE] Computed neighbors for 7352 samples in 47.289s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.391s
# [t-SNE] Iteration 50: error = 84.6534348, gradient norm = 0.0342081 (50 iterations in 2.615s)
# [t-SNE] Iteration 100: error = 76.0567856, gradient norm = 0.0050935 (50 iterations in 2.366s)
# [t-SNE] Iteration 150: error = 74.9949188, gradient norm = 0.0023402 (50 iterations in 2.240s)
# [t-SNE] Iteration 200: error = 74.5138245, gradient norm = 0.0023023 (50 iterations in 2.461s)
# [t-SNE] Iteration 250: error = 74.2818680, gradient norm = 0.0013146 (50 iterations in 2.374s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.281868
# [t-SNE] Iteration 300: error = 2.1923215, gradient norm = 0.0011699 (50 iterations in 2.523s)
# [t-SNE] Iteration 350: error = 1.7953210, gradient norm = 0.0004968 (50 iterations in 2.191s)
# [t-SNE] Iteration 400: error = 1.6227248, gradient norm = 0.0002879 (50 iterations in 2.130s)
# [t-SNE] Iteration 450: error = 1.5256977, gradient norm = 0.0001983 (50 iterations in 2.519s)
# [t-SNE] Iteration 500: error = 1.4633272, gradient norm = 0.0001479 (50 iterations in 2.166s)
# [t-SNE] Iteration 550: error = 1.4202943, gradient norm = 0.0001209 (50 iterations in 2.375s)
# [t-SNE] Iteration 600: error = 1.3897190, gradient norm = 0.0001003 (50 iterations in 2.909s)
# [t-SNE] Iteration 650: error = 1.3671849, gradient norm = 0.0000880 (50 iterations in 2.764s)
# [t-SNE] Iteration 700: error = 1.3505862, gradient norm = 0.0000788 (50 iterations in 2.424s)
# [t-SNE] Iteration 750: error = 1.3378464, gradient norm = 0.0000707 (50 iterations in 2.330s)
# [t-SNE] Iteration 800: error = 1.3278958, gradient norm = 0.0000673 (50 iterations in 2.458s)
# [t-SNE] Iteration 850: error = 1.3197111, gradient norm = 0.0000627 (50 iterations in 2.453s)
# [t-SNE] Iteration 900: error = 1.3130379, gradient norm = 0.0000596 (50 iterations in 2.289s)
# [t-SNE] Iteration 950: error = 1.3073506, gradient norm = 0.0000579 (50 iterations in 2.627s)
# [t-SNE] Iteration 1000: error = 1.3025234, gradient norm = 0.0000548 (50 iterations in 2.647s)
# [t-SNE] KL divergence after 1000 iterations: 1.302523
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %%
##  Modeling with linear SVC

# %%
from sklearn.model_selection import train_test_split

y = train.Activity
X = train.drop(['subject', 'Activity'], axis=1)
y_test = test.Activity
X_test = test.drop(['subject', 'Activity'], axis=1)
print('Training data size : ', X.shape)
print('Test data size : ', X_test.shape)
# Out:
# Training data size :  (7352, 562)
# Test data size :  (2947, 562)

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn import linear_model
from sklearn import metrics

# %%
train['Activity'].groupby(train['Activity']).count()
# Out:
# Activity
# LAYING                1407
# SITTING               1286
# STANDING              1374
# WALKING               1226
# WALKING_DOWNSTAIRS     986
# WALKING_UPSTAIRS      1073
# Name: Activity, dtype: int64

# %%
activity = train['Activity'].groupby(train['Activity']).count().index
activity_data = train['Activity'].groupby(train['Activity']).count().values
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b","#a4d321"]
plt.pie(activity_data, labels=activity,  colors=colors , autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("% of Different categories")
plt.show()

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from datetime import datetime

def perform_model(model, X, y, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X, y)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results
