# %% [markdown]
#  <H1> Human Activity Recognition Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.manifold import TSNE

# %%
train = pd.read_csv('./project_dataset/train.csv')
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
train.shape
# Out:
# (7352, 563)

# %%
test = pd.read_csv('./project_dataset/test.csv')
test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
# 2         -0.963483         -0.939260  ...                        -0.640736
# 3         -0.968897         -0.938610  ...                        -0.736124
# 4         -0.977346         -0.938610  ...                        -0.846595
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                              0.162920
# 1                    -0.083495                              0.017500
# 2                    -0.034956                              0.202302
# 3                    -0.017067                              0.154438
# 4                    -0.002223                             -0.040046
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.825886                              0.271151
# 1                         -0.434375                              0.920593
# 2                          0.064103                              0.145068
# 3                          0.340134                              0.296407
# 4                          0.736715                             -0.118545
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  subject  \
# 0             -0.720009              0.276801             -0.057978        2
# 1             -0.698091              0.281343             -0.083898        2
# 2             -0.702771              0.280083             -0.079346        2
# 3             -0.698954              0.284114             -0.077108        2
# 4             -0.692245              0.290722             -0.073857        2
#
#    Activity
# 0  STANDING
# 1  STANDING
# 2  STANDING
# 3  STANDING
# 4  STANDING
#
# [5 rows x 563 columns]

# %%
train.shape
# Out:
# (7352, 563)

# %% [markdown]
# *italicized text*<H2> Data Cleaning <H2>

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %%
#check for data imbalance

# %%
sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize =(20,10))
plt.title('Data provided by each user',fontsize=24)
sns.countplot(x='subject',hue='Activity',data=train)
plt.show()

# %%
plt.title('No of datapoints per activity',fontsize=16)
sns.countplot(train.Activity)
plt.xticks(rotation=90)
plt.show()

# %%
train.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
columns = train.columns

#Removing '()' from column names

columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]','')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

train.columns
test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
train.to_csv('f_train.csv',index=False)
test.to_csv('f_test.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-14-57402640507c> in <module>
#       1 train.to_csv('f_train.csv',index=False)
# ----> 2 test.to_csv('f_test.csv',index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'f_test.csv'

# %% [markdown]
# <H2> Exploratory Data Analysis<H2>
#
#     Feature Engineering

# %% [markdown]
# `1.` <b>Static and Dynamic Activities<b>
#
# `-->`Static Activities --> sit,stand,lie down
#
# `-->`Dynamic Activities --> Walking, Walking_upstairs,Walking_upstairs

# %%
sns.set_palette("colorblind", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='Activity', height=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()


plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops= dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))


plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops= dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %%
# For plotting purposes taking datapoints of each activity to a different dataframes


df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(12,8))

plt.subplot(1,2,1)

plt.title("Static Activities(Closer view)")
sns.distplot(train[train["Activity"]=="SITTING"]['tBodyAccMagmean'],hist = False ,label = 'Sitting')

sns.distplot(train[train["Activity"]=="STANDING"]['tBodyAccMagmean'],hist = False ,label = 'Standing')

sns.distplot(train[train["Activity"]=="LAYING"]['tBodyAccMagmean'],hist = False ,label = 'Laying')

plt.legend()


plt.axis([-1.02, -0.5, 0, 35])
plt.subplot(1,2,2)

plt.title("Dynamic Activities(closer view)")

sns.distplot(train[train["Activity"]=="WALKING"]['tBodyAccMagmean'],hist = False ,label = 'Walking')

sns.distplot(train[train["Activity"]=="WALKING_DOWNSTAIRS"]['tBodyAccMagmean'],hist = False ,label = 'Walking_upstairs')

sns.distplot(train[train["Activity"]=="WALKING_UPSTAIRS"]['tBodyAccMagmean'],hist = False ,label = 'Walking_downstairs')

plt.legend()

# %% [markdown]
# <h3>3.  Magnitude of an acceleration can separate it well<h3>

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='Activity',y='tBodyAccMagmean',data=train,showfliers = False ,saturation=1)

plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7,xmin=0.0,xmax=0.7,dashes=(5,5),c='g')
plt.axhline(y=-0.5,xmin=0.4,dashes=(5,5),c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h2> Observation <h3>
#
# -->If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
#
# -->If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
#
# -->If tAccMean > 0.0 then the Activity is WalkingDownstairs.
#
# -->We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# <h4>4. Position of GravityAccelerationComponants also matters <h4>

# %%
sns.boxplot(x='Activity',y='angleXgravityMean',data=train)
plt.axhline(y=0.08,xmin=0.1,xmax=0.9,c='m',dashes=(5,3))
plt.title("Angle between X-axis and Gravity_mean",fontsize=15)
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# <h3>Observations:<h3>
#
# If angleX,gravityMean > 0 then Activity is Laying.
#
# We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='Activity', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# <h3>Observations:<h3>
#
# If angleYgravityMean < -0.2 then Activity is Laying.
#
# We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %% [markdown]
# Here we will see these datapoints in 2 dimensions and try to observe the behaviour of the datapoints

# %% [markdown]
# <H2> Apply t-sne on the data<H2>

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=3000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity'], axis=1)
y_pre_tsne = train['Activity']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[5,10,20,30,50])
# Out:
# performing tsne with perplexity 5 and with 3000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.777s...
# [t-SNE] Computed neighbors for 7352 samples in 40.598s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.045s
# [t-SNE] Iteration 50: error = 114.1053391, gradient norm = 0.0209482 (50 iterations in 2.077s)
# [t-SNE] Iteration 100: error = 97.7968369, gradient norm = 0.0156141 (50 iterations in 2.329s)
# [t-SNE] Iteration 150: error = 93.4138031, gradient norm = 0.0116032 (50 iterations in 1.589s)
# [t-SNE] Iteration 200: error = 91.4261780, gradient norm = 0.0070718 (50 iterations in 1.400s)
# [t-SNE] Iteration 250: error = 90.2345123, gradient norm = 0.0056353 (50 iterations in 1.559s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.234512
# [t-SNE] Iteration 300: error = 3.5852315, gradient norm = 0.0014689 (50 iterations in 2.336s)
# [t-SNE] Iteration 350: error = 2.8231668, gradient norm = 0.0007535 (50 iterations in 1.993s)
# [t-SNE] Iteration 400: error = 2.4407423, gradient norm = 0.0005315 (50 iterations in 1.444s)
# [t-SNE] Iteration 450: error = 2.2226789, gradient norm = 0.0004073 (50 iterations in 1.272s)
# [t-SNE] Iteration 500: error = 2.0771585, gradient norm = 0.0003328 (50 iterations in 1.268s)
# [t-SNE] Iteration 550: error = 1.9715278, gradient norm = 0.0002843 (50 iterations in 1.291s)
# [t-SNE] Iteration 600: error = 1.8901767, gradient norm = 0.0002471 (50 iterations in 1.276s)
# [t-SNE] Iteration 650: error = 1.8249518, gradient norm = 0.0002196 (50 iterations in 1.332s)
# [t-SNE] Iteration 700: error = 1.7709835, gradient norm = 0.0001985 (50 iterations in 1.308s)
# [t-SNE] Iteration 750: error = 1.7254728, gradient norm = 0.0001778 (50 iterations in 1.288s)
# [t-SNE] Iteration 800: error = 1.6864525, gradient norm = 0.0001635 (50 iterations in 1.301s)
# [t-SNE] Iteration 850: error = 1.6524978, gradient norm = 0.0001532 (50 iterations in 1.269s)
# [t-SNE] Iteration 900: error = 1.6226617, gradient norm = 0.0001417 (50 iterations in 1.453s)
# [t-SNE] Iteration 950: error = 1.5958707, gradient norm = 0.0001341 (50 iterations in 1.283s)
# [t-SNE] Iteration 1000: error = 1.5719355, gradient norm = 0.0001259 (50 iterations in 1.273s)
# [t-SNE] KL divergence after 1000 iterations: 1.571936
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 3000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.766s...
# [t-SNE] Computed neighbors for 7352 samples in 34.824s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.078s
# [t-SNE] Iteration 50: error = 105.5558243, gradient norm = 0.0225585 (50 iterations in 1.974s)
# [t-SNE] Iteration 100: error = 90.5199890, gradient norm = 0.0106811 (50 iterations in 1.672s)
# [t-SNE] Iteration 150: error = 87.4946213, gradient norm = 0.0052635 (50 iterations in 1.858s)
# [t-SNE] Iteration 200: error = 86.2645111, gradient norm = 0.0042241 (50 iterations in 2.307s)
# [t-SNE] Iteration 250: error = 85.5715485, gradient norm = 0.0034613 (50 iterations in 2.042s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.571548
# [t-SNE] Iteration 300: error = 3.1426110, gradient norm = 0.0013904 (50 iterations in 2.663s)
# [t-SNE] Iteration 350: error = 2.4993887, gradient norm = 0.0006494 (50 iterations in 2.111s)
# [t-SNE] Iteration 400: error = 2.1799040, gradient norm = 0.0004230 (50 iterations in 1.649s)
# [t-SNE] Iteration 450: error = 1.9959011, gradient norm = 0.0003145 (50 iterations in 1.469s)
# [t-SNE] Iteration 500: error = 1.8776128, gradient norm = 0.0002550 (50 iterations in 1.391s)
# [t-SNE] Iteration 550: error = 1.7942739, gradient norm = 0.0002120 (50 iterations in 1.422s)
# [t-SNE] Iteration 600: error = 1.7316909, gradient norm = 0.0001830 (50 iterations in 1.759s)
# [t-SNE] Iteration 650: error = 1.6827242, gradient norm = 0.0001613 (50 iterations in 2.367s)
# [t-SNE] Iteration 700: error = 1.6427894, gradient norm = 0.0001445 (50 iterations in 2.318s)
# [t-SNE] Iteration 750: error = 1.6099850, gradient norm = 0.0001313 (50 iterations in 1.774s)
# [t-SNE] Iteration 800: error = 1.5825009, gradient norm = 0.0001212 (50 iterations in 2.792s)
# [t-SNE] Iteration 850: error = 1.5592288, gradient norm = 0.0001120 (50 iterations in 2.484s)
# [t-SNE] Iteration 900: error = 1.5390544, gradient norm = 0.0001049 (50 iterations in 2.286s)
# [t-SNE] Iteration 950: error = 1.5214015, gradient norm = 0.0000961 (50 iterations in 2.198s)
# [t-SNE] Iteration 1000: error = 1.5056748, gradient norm = 0.0000908 (50 iterations in 1.682s)
# [t-SNE] KL divergence after 1000 iterations: 1.505675
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 3000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.783s...
# [t-SNE] Computed neighbors for 7352 samples in 34.214s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.154s
# [t-SNE] Iteration 50: error = 97.8584442, gradient norm = 0.0144276 (50 iterations in 1.943s)
# [t-SNE] Iteration 100: error = 84.0144119, gradient norm = 0.0057323 (50 iterations in 2.068s)
# [t-SNE] Iteration 150: error = 82.0210342, gradient norm = 0.0034348 (50 iterations in 1.612s)
# [t-SNE] Iteration 200: error = 81.2513046, gradient norm = 0.0025490 (50 iterations in 1.551s)
# [t-SNE] Iteration 250: error = 80.8359604, gradient norm = 0.0017203 (50 iterations in 1.547s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.835960
# [t-SNE] Iteration 300: error = 2.7044144, gradient norm = 0.0012982 (50 iterations in 1.525s)
# [t-SNE] Iteration 350: error = 2.1701086, gradient norm = 0.0005732 (50 iterations in 1.683s)
# [t-SNE] Iteration 400: error = 1.9205451, gradient norm = 0.0003474 (50 iterations in 1.537s)
# [t-SNE] Iteration 450: error = 1.7742202, gradient norm = 0.0002479 (50 iterations in 1.553s)
# [t-SNE] Iteration 500: error = 1.6800277, gradient norm = 0.0001929 (50 iterations in 1.465s)
# [t-SNE] Iteration 550: error = 1.6157705, gradient norm = 0.0001584 (50 iterations in 1.588s)
# [t-SNE] Iteration 600: error = 1.5690956, gradient norm = 0.0001343 (50 iterations in 1.521s)
# [t-SNE] Iteration 650: error = 1.5338237, gradient norm = 0.0001180 (50 iterations in 1.773s)
# [t-SNE] Iteration 700: error = 1.5062840, gradient norm = 0.0001055 (50 iterations in 1.568s)
# [t-SNE] Iteration 750: error = 1.4841479, gradient norm = 0.0000946 (50 iterations in 1.472s)
# [t-SNE] Iteration 800: error = 1.4662645, gradient norm = 0.0000880 (50 iterations in 1.490s)
# [t-SNE] Iteration 850: error = 1.4513985, gradient norm = 0.0000826 (50 iterations in 2.109s)
# [t-SNE] Iteration 900: error = 1.4393588, gradient norm = 0.0000784 (50 iterations in 1.715s)
# [t-SNE] Iteration 950: error = 1.4295381, gradient norm = 0.0000765 (50 iterations in 1.531s)
# [t-SNE] Iteration 1000: error = 1.4215443, gradient norm = 0.0000738 (50 iterations in 1.557s)
# [t-SNE] KL divergence after 1000 iterations: 1.421544
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 30 and with 3000 iterations at max
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 1.156s...
# [t-SNE] Computed neighbors for 7352 samples in 38.332s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.348516
# [t-SNE] Computed conditional probabilities in 0.229s
# [t-SNE] Iteration 50: error = 93.1685944, gradient norm = 0.0114099 (50 iterations in 2.638s)
# [t-SNE] Iteration 100: error = 80.6573792, gradient norm = 0.0054314 (50 iterations in 1.911s)
# [t-SNE] Iteration 150: error = 78.8771820, gradient norm = 0.0026772 (50 iterations in 1.859s)
# [t-SNE] Iteration 200: error = 78.3286514, gradient norm = 0.0018819 (50 iterations in 1.741s)
# [t-SNE] Iteration 250: error = 78.0426025, gradient norm = 0.0016421 (50 iterations in 1.760s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.042603
# [t-SNE] Iteration 300: error = 2.4551888, gradient norm = 0.0012484 (50 iterations in 2.975s)
# [t-SNE] Iteration 350: error = 1.9836520, gradient norm = 0.0005380 (50 iterations in 3.225s)
# [t-SNE] Iteration 400: error = 1.7707477, gradient norm = 0.0003175 (50 iterations in 2.331s)
# [t-SNE] Iteration 450: error = 1.6484578, gradient norm = 0.0002197 (50 iterations in 2.031s)
# [t-SNE] Iteration 500: error = 1.5691295, gradient norm = 0.0001674 (50 iterations in 2.475s)
# [t-SNE] Iteration 550: error = 1.5152688, gradient norm = 0.0001356 (50 iterations in 2.216s)
# [t-SNE] Iteration 600: error = 1.4769493, gradient norm = 0.0001169 (50 iterations in 1.883s)
# [t-SNE] Iteration 650: error = 1.4485567, gradient norm = 0.0001037 (50 iterations in 1.693s)
# [t-SNE] Iteration 700: error = 1.4275388, gradient norm = 0.0000945 (50 iterations in 1.990s)
# [t-SNE] Iteration 750: error = 1.4115220, gradient norm = 0.0000860 (50 iterations in 1.634s)
# [t-SNE] Iteration 800: error = 1.3987516, gradient norm = 0.0000790 (50 iterations in 2.195s)
# [t-SNE] Iteration 850: error = 1.3882290, gradient norm = 0.0000754 (50 iterations in 2.540s)
# [t-SNE] Iteration 900: error = 1.3799863, gradient norm = 0.0000722 (50 iterations in 1.940s)
# [t-SNE] Iteration 950: error = 1.3731706, gradient norm = 0.0000710 (50 iterations in 1.642s)
# [t-SNE] Iteration 1000: error = 1.3678497, gradient norm = 0.0000671 (50 iterations in 1.620s)
# [t-SNE] KL divergence after 1000 iterations: 1.367850
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 3000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.775s...
# [t-SNE] Computed neighbors for 7352 samples in 41.054s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.363s
# [t-SNE] Iteration 50: error = 86.2665634, gradient norm = 0.0230605 (50 iterations in 2.685s)
# [t-SNE] Iteration 100: error = 75.8121033, gradient norm = 0.0043861 (50 iterations in 2.841s)
# [t-SNE] Iteration 150: error = 74.7587585, gradient norm = 0.0024713 (50 iterations in 2.298s)
# [t-SNE] Iteration 200: error = 74.3463135, gradient norm = 0.0021655 (50 iterations in 2.296s)
# [t-SNE] Iteration 250: error = 74.1457443, gradient norm = 0.0011506 (50 iterations in 2.301s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.145744
# [t-SNE] Iteration 300: error = 2.1483321, gradient norm = 0.0011730 (50 iterations in 2.083s)
# [t-SNE] Iteration 350: error = 1.7572398, gradient norm = 0.0004906 (50 iterations in 1.974s)
# [t-SNE] Iteration 400: error = 1.5892791, gradient norm = 0.0002817 (50 iterations in 1.923s)
# [t-SNE] Iteration 450: error = 1.4956164, gradient norm = 0.0001909 (50 iterations in 1.976s)
# [t-SNE] Iteration 500: error = 1.4351915, gradient norm = 0.0001427 (50 iterations in 1.952s)
# [t-SNE] Iteration 550: error = 1.3940151, gradient norm = 0.0001135 (50 iterations in 1.942s)
# [t-SNE] Iteration 600: error = 1.3644030, gradient norm = 0.0000967 (50 iterations in 1.987s)
# [t-SNE] Iteration 650: error = 1.3428423, gradient norm = 0.0000821 (50 iterations in 2.151s)
# [t-SNE] Iteration 700: error = 1.3272238, gradient norm = 0.0000735 (50 iterations in 2.213s)
# [t-SNE] Iteration 750: error = 1.3158895, gradient norm = 0.0000673 (50 iterations in 2.083s)
# [t-SNE] Iteration 800: error = 1.3073134, gradient norm = 0.0000646 (50 iterations in 2.293s)
# [t-SNE] Iteration 850: error = 1.3003964, gradient norm = 0.0000613 (50 iterations in 2.013s)
# [t-SNE] Iteration 900: error = 1.2952650, gradient norm = 0.0000580 (50 iterations in 2.001s)
# [t-SNE] Iteration 950: error = 1.2911671, gradient norm = 0.0000543 (50 iterations in 2.024s)
# [t-SNE] Iteration 1000: error = 1.2873918, gradient norm = 0.0000541 (50 iterations in 2.069s)
# [t-SNE] KL divergence after 1000 iterations: 1.287392
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %%
## modeling with linear svc

# %%
from sklearn.model_selection import train_test_split

y = train.Activity
X = train.drop(['subject', 'Activity'], axis=1)
y_test = test.Activity
X_test = test.drop(['subject', 'Activity'], axis=1)
print('Training data size : ', X.shape)
print('Test data size : ', X_test.shape)
# Out:
# Training data size :  (7352, 561)
# Test data size :  (2947, 561)

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn import linear_model
from sklearn import metrics

# %%
train['Activity'].groupby(train['Activity']).count()
# Out:
# Activity
# LAYING                1407
# SITTING               1286
# STANDING              1374
# WALKING               1226
# WALKING_DOWNSTAIRS     986
# WALKING_UPSTAIRS      1073
# Name: Activity, dtype: int64

# %%
activity = train['Activity'].groupby(train['Activity']).count().index
activity_data = train['Activity'].groupby(train['Activity']).count().values
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b","#a4d321"]
plt.pie(activity_data, labels=activity,  colors=colors , autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("% of Different categories")
plt.show()

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from datetime import datetime

def perform_model(model, X, y, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X, y)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %%
parameters = {'C':[0.125, 0.5, 1, 2, 8, 16]}
lr_svc = LinearSVC(tol=0.00005)
lr_svc_grid = GridSearchCV(lr_svc, param_grid=parameters, n_jobs=-1, verbose=1)
lr_svc_grid_results = perform_model(lr_svc_grid, X, y, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   44.6s finished
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:48.925473
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.012966
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9667458432304038
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  2 428  58   0   0   3]
#  [  0   9 522   1   0   0]
#  [  0   0   0 496   0   0]
#  [  0   0   0   3 412   5]
#  [  0   0   0  17   0 454]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.87      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947
